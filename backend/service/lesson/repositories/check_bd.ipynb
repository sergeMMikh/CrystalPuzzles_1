# %%
import sys
import os

# Укажите путь к корню проекта
# project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
project_root = "/home/smm/CrystalPuzzles_1/backend"
if project_root not in sys.path:
    sys.path.append(project_root)

from sqlalchemy.ext.asyncio import create_async_engine, AsyncSession
from sqlalchemy.orm import sessionmaker
from sqlalchemy import insert, select, exists
from service.lesson.models import Check, TrainingCheck
import asyncio

# %%
print("Project root added to sys.path:", project_root)
print(os.getcwd())
# Out:
# Project root added to sys.path: /home/smm/CrystalPuzzles_1/backend
# /home/smm/CrystalPuzzles_1/backend/service/lesson/repositories

# %%
DATABASE_URL = "postgresql+asyncpg://crystal:crystal@localhost/crystal"

# Создание асинхронного двигателя и сессии
engine = create_async_engine(DATABASE_URL, echo=True)
async_session = sessionmaker(engine, class_=AsyncSession, expire_on_commit=False)

# %%
async def checks_exist(session: AsyncSession, lesson_id: int):
    stmt = (
        select(exists(Check))
        .filter(Check.lesson_id == lesson_id)
        .limit(1)
    )
    result = await session.execute(stmt)
    return result.scalar_one_or_none()

# %%
async with async_session() as session:
        # Вставка данных в TrainingCheck
        # training_check_data = {
        #     "training_id": 1,
        #     "check_id": 2
        # }
        # result = await bind_training_check(session, training_check_data)
        # print("Inserted TrainingCheck:", result)

        # Проверка существования записей
        lesson_id = 1
        exists = await checks_exist(session, lesson_id)
        print(f"Does lesson_id {lesson_id} exist in Check? {exists}")
# Out:
# 2024-12-18 22:48:12,880 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-12-18 22:48:12,882 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-18 22:48:12,890 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-12-18 22:48:12,891 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-18 22:48:12,898 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-12-18 22:48:12,899 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-18 22:48:12,906 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-18 22:48:12,918 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/share/virtualenvs/backend-ZK8ukel1/lib/python3.11/site-packages/sqlalchemy/orm/clsregistry.py:516, in _class_resolver._resolve_name(self)
#     515 if rval is None:
# --> 516     rval = d[token]
#     517 else:
#
# ...
